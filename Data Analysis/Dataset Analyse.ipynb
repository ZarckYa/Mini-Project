# %%
# Import libraries
import pandas as pd
import numpy as np

# %% [markdown]
# ### VDJdb columns explanation
# gene column contains TRA and TRB, TRA means TCR alpha subunit, TRB means TCR beta subunit.
#
# cdr3 column is the segment to join the TRA and TRB together.
#
# v.segm and j.segm columns is part of TRA or TRB.
#
# sepecies column is represent where is gene from, here is HomoSapiens, also called human(All of us).
#
# Before explaning columns, we need to know what is MHC. MHC means Major histocompatibility complex, which contail 2 classes.
# MHC I class and MHC II class (Here is mhc.class, MHCI and MHCII). Both classes of proteins share the task of presenting peptides on the cell surface for recognition by T cells.There is a set of alleles that will determine the protein type and form of MHCI(Here, mhc.a and mhc.b is expressed from alleles gene regions(Maybe, i am not sure)), more details please click https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5355494/#:~:text=Major%20histocompatibility%20complex%20(MHC)%20class%20I%20and%20class%20II%20proteins,for%20recognition%20by%20T%20cells.
#
# mhc.a and mhc.b columns is one gene expression based on mhc.class.
#
# mhc.class column is to specify a class the gene belong to.
#
# antigen.epitope column , also known as antigenic determinant, is the part of an antigen that is recognized by the immune system, specifically by antibodies, B cells, or T cells. The part of an antibody that binds to the epitope is called a paratope.
#
# antigen.species columns is show us where is the paratope or epitope from, here the mhc's paratope from HIV-1.
#
# More columns details, Please click: https://github.com/antigenomics/vdjdb-db

# %%
# read VDjdb dataset
VDJdb = pd.read_csv("vdjdb.txt", sep = "\t")
#display(VDJdb)
VDJdb.head()
# Out:
#    complex.id gene                  cdr3       v.segm      j.segm  \
# 0           1  TRA         CIVRAPGRADMRF  TRAV26-1*01   TRAJ43*01
# 1           1  TRB  CASSYLPGQGDHYSNQPQHF    TRBV13*01  TRBJ1-5*01
# 2           0  TRB   CASSFEAGQGFFSNQPQHF    TRBV13*01  TRBJ1-5*01
# 3           2  TRA        CAVPSGAGSYQLTF    TRAV20*01   TRAJ28*01
# 4           2  TRB   CASSFEPGQGFYSNQPQHF    TRBV13*01  TRBJ1-5*01
#
#        species     mhc.a mhc.b mhc.class antigen.epitope  ... antigen.species  \
# 0  HomoSapiens  HLA-B*08   B2M      MHCI        FLKEKGGL  ...           HIV-1
# 1  HomoSapiens  HLA-B*08   B2M      MHCI        FLKEKGGL  ...           HIV-1
# 2  HomoSapiens  HLA-B*08   B2M      MHCI        FLKEKGGL  ...           HIV-1
# 3  HomoSapiens  HLA-B*08   B2M      MHCI        FLKEKGGL  ...           HIV-1
# 4  HomoSapiens  HLA-B*08   B2M      MHCI        FLKEKGGL  ...           HIV-1
#
#     reference.id                                             method  \
# 0  PMID:15596521  {"frequency": "", "identification": "tetramer-...
# 1  PMID:15596521  {"frequency": "", "identification": "tetramer-...
# 2  PMID:15596521  {"frequency": "", "identification": "tetramer-...
# 3  PMID:15596521  {"frequency": "", "identification": "tetramer-...
# 4  PMID:15596521  {"frequency": "", "identification": "tetramer-...
#
#                                                 meta  \
# 0  {"cell.subset": "CD8+", "clone.id": "", "donor...
# 1  {"cell.subset": "CD8+", "clone.id": "", "donor...
# 2  {"cell.subset": "CD8+", "clone.id": "", "donor...
# 3  {"cell.subset": "CD8+", "clone.id": "", "donor...
# 4  {"cell.subset": "CD8+", "clone.id": "", "donor...
#
#                                              cdr3fix vdjdb.score  web.method  \
# 0  {"cdr3": "CIVRAPGRADMRF", "cdr3_old": "CIVRAPG...           2        sort
# 1  {"cdr3": "CASSYLPGQGDHYSNQPQHF", "cdr3_old": "...           2        sort
# 2  {"cdr3": "CASSFEAGQGFFSNQPQHF", "cdr3_old": "C...           2        sort
# 3  {"cdr3": "CAVPSGAGSYQLTF", "cdr3_old": "CAVPSG...           2        sort
# 4  {"cdr3": "CASSFEPGQGFYSNQPQHF", "cdr3_old": "C...           2        sort
#
#   web.method.seq web.cdr3fix.nc web.cdr3fix.unmp
# 0         sanger             no               no
# 1         sanger             no               no
# 2         sanger             no               no
# 3         sanger             no               no
# 4         sanger             no               no
#
# [5 rows x 21 columns]

# %%
# read VDJdb full dataset
VDJdb_full = pd.read_csv("vdjdb_full.txt", sep = "\t", low_memory=False)
display(VDJdb_full)
# Out:
#             cdr3.alpha          v.alpha    j.alpha             cdr3.beta  \
# 0        CIVRAPGRADMRF      TRAV26-1*01  TRAJ43*01  CASSYLPGQGDHYSNQPQHF
# 1                  NaN              NaN        NaN   CASSFEAGQGFFSNQPQHF
# 2       CAVPSGAGSYQLTF        TRAV20*01  TRAJ28*01   CASSFEPGQGFYSNQPQHF
# 3          CAVKASGSRLT         TRAV2*01        NaN  CASSYEPGQVSHYSNQPQHF
# 4        CAYRPPGTYKYIF  TRAV38-2/DV8*01  TRAJ40*01        CASSALASLNEQFF
# ...                ...              ...        ...                   ...
# 60050              NaN              NaN        NaN        CASSDWGSAETLYF
# 60051    CAARGYNQGKLIF      TRAV14-2*01  TRAJ23*01                   NaN
# 60052    CATSDTNAYKVIF       TRAV8-2*01  TRAJ30*01                   NaN
# 60053  CALSDTGANTGKLTF       TRAV6-5*01  TRAJ52*01                   NaN
# 60054    CALRGNNNNRIFF      TRAV9D-4*01  TRAJ31*01                   NaN
#
#             v.beta d.beta      j.beta      species     mhc.a mhc.b  ...  \
# 0        TRBV13*01    NaN  TRBJ1-5*01  HomoSapiens  HLA-B*08   B2M  ...
# 1        TRBV13*01    NaN  TRBJ1-5*01  HomoSapiens  HLA-B*08   B2M  ...
# 2        TRBV13*01    NaN  TRBJ1-5*01  HomoSapiens  HLA-B*08   B2M  ...
# 3        TRBV13*01    NaN  TRBJ1-5*01  HomoSapiens  HLA-B*08   B2M  ...
# 4        TRBV14*01    NaN  TRBJ2-1*01  HomoSapiens  HLA-B*08   B2M  ...
# ...            ...    ...         ...          ...       ...   ...  ...
# 60050  TRBV13-3*01    NaN  TRBJ2-3*01  MusMusculus     H-2Db   B2M  ...
# 60051          NaN    NaN         NaN  MusMusculus     H-2Db   B2M  ...
# 60052          NaN    NaN         NaN  MusMusculus     H-2Db   B2M  ...
# 60053          NaN    NaN         NaN  MusMusculus     H-2Db   B2M  ...
# 60054          NaN    NaN         NaN  MusMusculus     H-2Db   B2M  ...
#
#                  meta.replica.id meta.clone.id meta.epitope.id meta.tissue  \
# 0                            NaN           NaN             NaN        PBMC
# 1                            NaN           NaN             NaN        PBMC
# 2                            NaN           NaN             NaN        PBMC
# 3                            NaN           NaN             NaN        PBMC
# 4                            NaN           NaN             NaN        PBMC
# ...                          ...           ...             ...         ...
# 60050      KL83_CB6F1_#5_21714KL           NaN             NaN         NaN
# 60051  KL136_CB6F1_#5_TRA_271114           NaN             NaN         NaN
# 60052  KL136_CB6F1_#5_TRA_271114           NaN             NaN         NaN
# 60053  KL136_CB6F1_#5_TRA_271114           NaN             NaN         NaN
# 60054  KL136_CB6F1_#5_TRA_271114           NaN             NaN         NaN
#
#                                           meta.donor.MHC  \
# 0      HLA-A*02:01,HLA-A*24:02;HLA-B*08:01,HLA-B*5701...
# 1      HLA-A*01:01,HLA-A*02:01;HLA-B*08:01,HLA-B*57:0...
# 2      HLA-A*02,HLA-A*24:02;HLA-B*08:01,HLA-B*15;HLA-...
# 3      HLA-A*01:01,HLA-A*02:01;HLA-B*08:01,HLA-B*57:0...
# 4      HLA-A*01:01,HLA-A*02:01;HLA-B*08:01,HLA-B*57:0...
# ...                                                  ...
# 60050                                              H2d/b
# 60051                                              H2d/b
# 60052                                              H2d/b
# 60053                                              H2d/b
# 60054                                              H2d/b
#
#       meta.donor.MHC.method meta.structure.id  \
# 0                       NaN               NaN
# 1                       NaN               NaN
# 2                       NaN               NaN
# 3                       NaN               NaN
# 4                       NaN               NaN
# ...                     ...               ...
# 60050                   NaN               NaN
# 60051                   NaN               NaN
# 60052                   NaN               NaN
# 60053                   NaN               NaN
# 60054                   NaN               NaN
#
#                                            cdr3fix.alpha  \
# 0      {"cdr3": "CIVRAPGRADMRF", "cdr3_old": "CIVRAPG...
# 1                                                    NaN
# 2      {"cdr3": "CAVPSGAGSYQLTF", "cdr3_old": "CAVPSG...
# 3      {"cdr3": "CAVKASGSRLT", "cdr3_old": "CAVKASGSR...
# 4      {"cdr3": "CAYRPPGTYKYIF", "cdr3_old": "CAYRPPG...
# ...                                                  ...
# 60050                                                NaN
# 60051  {"cdr3": "CAARGYNQGKLIF", "cdr3_old": "CAARGYN...
# 60052  {"cdr3": "CATSDTNAYKVIF", "cdr3_old": "CATSDTN...
# 60053  {"cdr3": "CALSDTGANTGKLTF", "cdr3_old": "CALSD...
# 60054  {"cdr3": "CALRGNNNNRIFF", "cdr3_old": "CALRGNN...
#
#                                             cdr3fix.beta vdjdb.score
# 0      {"cdr3": "CASSYLPGQGDHYSNQPQHF", "cdr3_old": "...           2
# 1      {"cdr3": "CASSFEAGQGFFSNQPQHF", "cdr3_old": "C...           2
# 2      {"cdr3": "CASSFEPGQGFYSNQPQHF", "cdr3_old": "C...           2
# 3      {"cdr3": "CASSYEPGQVSHYSNQPQHF", "cdr3_old": "...           2
# 4      {"cdr3": "CASSALASLNEQFF", "cdr3_old": "CASSAL...           2
# ...                                                  ...         ...
# 60050  {"cdr3": "CASSDWGSAETLYF", "cdr3_old": "CASSDW...           0
# 60051                                                NaN           1
# 60052                                                NaN           1
# 60053                                                NaN           0
# 60054                                                NaN           0
#
# [60055 rows x 34 columns]

# %% [markdown]
# Based on my understanding of the original data and its background knowledge. Its useful data are listed as (cdr3.alpha, v.alpha, j.alpha, cdr3.beta, v.beta, d.beta, j.beta, species).
# Our second step is to derive the similarity matrix from the useful sequence data by means of a library of functions such as TCRDist. For documentation on the TCRDist functions, please click on https://tcrdist3.readthedocs.io/en/latest/welcome.html.
#
# Here, I am not sure if the v,j segment needs to be converted to a nucleotide sequence when calculating the similarity matrix for the TCR. If the v, j segment needs to be converted to a nucleotide sequence, please click on https://www.ncbi.nlm.nih.gov/pmc/articles/PMC9262623/. For the relevant Github code, and associated conversion data, click: https://github.com/JamieHeather/stitchr.

# %%
vdj_useful_db = VDJdb_full[["species", "cdr3.alpha", 
                            "v.alpha", "j.alpha", "cdr3.beta", 
                            "v.beta", "j.beta", "mhc.a", "mhc.b", "vdjdb.score"]]
display(vdj_useful_db)

vdj_db_fit_tcrdist = vdj_useful_db.rename(columns = {'cdr3.alpha': 'cdr3_a_aa', 'v.alpha': 'v_a_gene', 'j.alpha':'j_a_gene', 
                                          'cdr3.beta': 'cdr3_b_aa', 'v.beta':'v_b_gene', 'j.beta':'j_b_gene'})

vdj_db_fit_tcrdist_first_500 = vdj_db_fit_tcrdist.head(500)
display(vdj_db_fit_tcrdist_first_500)

full_db = VDJdb_full
# Out:
#            species       cdr3.alpha          v.alpha    j.alpha  \
# 0      HomoSapiens    CIVRAPGRADMRF      TRAV26-1*01  TRAJ43*01
# 1      HomoSapiens              NaN              NaN        NaN
# 2      HomoSapiens   CAVPSGAGSYQLTF        TRAV20*01  TRAJ28*01
# 3      HomoSapiens      CAVKASGSRLT         TRAV2*01        NaN
# 4      HomoSapiens    CAYRPPGTYKYIF  TRAV38-2/DV8*01  TRAJ40*01
# ...            ...              ...              ...        ...
# 60050  MusMusculus              NaN              NaN        NaN
# 60051  MusMusculus    CAARGYNQGKLIF      TRAV14-2*01  TRAJ23*01
# 60052  MusMusculus    CATSDTNAYKVIF       TRAV8-2*01  TRAJ30*01
# 60053  MusMusculus  CALSDTGANTGKLTF       TRAV6-5*01  TRAJ52*01
# 60054  MusMusculus    CALRGNNNNRIFF      TRAV9D-4*01  TRAJ31*01
#
#                   cdr3.beta       v.beta      j.beta     mhc.a mhc.b  \
# 0      CASSYLPGQGDHYSNQPQHF    TRBV13*01  TRBJ1-5*01  HLA-B*08   B2M
# 1       CASSFEAGQGFFSNQPQHF    TRBV13*01  TRBJ1-5*01  HLA-B*08   B2M
# 2       CASSFEPGQGFYSNQPQHF    TRBV13*01  TRBJ1-5*01  HLA-B*08   B2M
# 3      CASSYEPGQVSHYSNQPQHF    TRBV13*01  TRBJ1-5*01  HLA-B*08   B2M
# 4            CASSALASLNEQFF    TRBV14*01  TRBJ2-1*01  HLA-B*08   B2M
# ...                     ...          ...         ...       ...   ...
# 60050        CASSDWGSAETLYF  TRBV13-3*01  TRBJ2-3*01     H-2Db   B2M
# 60051                   NaN          NaN         NaN     H-2Db   B2M
# 60052                   NaN          NaN         NaN     H-2Db   B2M
# 60053                   NaN          NaN         NaN     H-2Db   B2M
# 60054                   NaN          NaN         NaN     H-2Db   B2M
#
#        vdjdb.score
# 0                2
# 1                2
# 2                2
# 3                2
# 4                2
# ...            ...
# 60050            0
# 60051            1
# 60052            1
# 60053            0
# 60054            0
#
# [60055 rows x 10 columns]
#          species       cdr3_a_aa         v_a_gene   j_a_gene  \
# 0    HomoSapiens   CIVRAPGRADMRF      TRAV26-1*01  TRAJ43*01
# 1    HomoSapiens             NaN              NaN        NaN
# 2    HomoSapiens  CAVPSGAGSYQLTF        TRAV20*01  TRAJ28*01
# 3    HomoSapiens     CAVKASGSRLT         TRAV2*01        NaN
# 4    HomoSapiens   CAYRPPGTYKYIF  TRAV38-2/DV8*01  TRAJ40*01
# ..           ...             ...              ...        ...
# 495  HomoSapiens             NaN              NaN        NaN
# 496  HomoSapiens             NaN              NaN        NaN
# 497  HomoSapiens             NaN              NaN        NaN
# 498  HomoSapiens             NaN              NaN        NaN
# 499  HomoSapiens             NaN              NaN        NaN
#
#                 cdr3_b_aa     v_b_gene    j_b_gene        mhc.a mhc.b  \
# 0    CASSYLPGQGDHYSNQPQHF    TRBV13*01  TRBJ1-5*01     HLA-B*08   B2M
# 1     CASSFEAGQGFFSNQPQHF    TRBV13*01  TRBJ1-5*01     HLA-B*08   B2M
# 2     CASSFEPGQGFYSNQPQHF    TRBV13*01  TRBJ1-5*01     HLA-B*08   B2M
# 3    CASSYEPGQVSHYSNQPQHF    TRBV13*01  TRBJ1-5*01     HLA-B*08   B2M
# 4          CASSALASLNEQFF    TRBV14*01  TRBJ2-1*01     HLA-B*08   B2M
# ..                    ...          ...         ...          ...   ...
# 495        CASSYFGVNSPLHF   TRBV6-1*01  TRBJ1-6*01  HLA-A*02:01   B2M
# 496      CATSALAGQGRDEQFF  TRBV24-1*01  TRBJ2-1*01  HLA-A*02:01   B2M
# 497        CASSRLAGTDTQYF  TRBV12-3*01  TRBJ2-3*01  HLA-A*02:01   B2M
# 498      CASSFPGYGLNTEAFF   TRBV6-1*01  TRBJ1-1*01  HLA-A*02:01   B2M
# 499       CASSVLAGGLDTQYF  TRBV10-2*01  TRBJ2-3*01  HLA-A*02:01   B2M
#
#      vdjdb.score
# 0              2
# 1              2
# 2              2
# 3              2
# 4              2
# ..           ...
# 495            0
# 496            0
# 497            0
# 498            0
# 499            0
#
# [500 rows x 10 columns]

# %%
# read VDjdb dataset
VDJdb = pd.read_csv("vdjdb.txt", sep = "\t")
display(VDJdb)
#VDJdb.head()
# Out:
#        complex.id gene                  cdr3       v.segm      j.segm  \
# 0               1  TRA         CIVRAPGRADMRF  TRAV26-1*01   TRAJ43*01
# 1               1  TRB  CASSYLPGQGDHYSNQPQHF    TRBV13*01  TRBJ1-5*01
# 2               0  TRB   CASSFEAGQGFFSNQPQHF    TRBV13*01  TRBJ1-5*01
# 3               2  TRA        CAVPSGAGSYQLTF    TRAV20*01   TRAJ28*01
# 4               2  TRB   CASSFEPGQGFYSNQPQHF    TRBV13*01  TRBJ1-5*01
# ...           ...  ...                   ...          ...         ...
# 89316           0  TRB        CASSDWGSAETLYF  TRBV13-3*01  TRBJ2-3*01
# 89317           0  TRA         CAARGYNQGKLIF  TRAV14-2*01   TRAJ23*01
# 89318           0  TRA         CATSDTNAYKVIF   TRAV8-2*01   TRAJ30*01
# 89319           0  TRA       CALSDTGANTGKLTF   TRAV6-5*01   TRAJ52*01
# 89320           0  TRA         CALRGNNNNRIFF  TRAV9D-4*01   TRAJ31*01
#
#            species     mhc.a mhc.b mhc.class antigen.epitope  ...  \
# 0      HomoSapiens  HLA-B*08   B2M      MHCI        FLKEKGGL  ...
# 1      HomoSapiens  HLA-B*08   B2M      MHCI        FLKEKGGL  ...
# 2      HomoSapiens  HLA-B*08   B2M      MHCI        FLKEKGGL  ...
# 3      HomoSapiens  HLA-B*08   B2M      MHCI        FLKEKGGL  ...
# 4      HomoSapiens  HLA-B*08   B2M      MHCI        FLKEKGGL  ...
# ...            ...       ...   ...       ...             ...  ...
# 89316  MusMusculus     H-2Db   B2M      MHCI       SQLLNAKYL  ...
# 89317  MusMusculus     H-2Db   B2M      MHCI       SQLLNAKYL  ...
# 89318  MusMusculus     H-2Db   B2M      MHCI       SQLLNAKYL  ...
# 89319  MusMusculus     H-2Db   B2M      MHCI       SQLLNAKYL  ...
# 89320  MusMusculus     H-2Db   B2M      MHCI       SQLLNAKYL  ...
#
#          antigen.species   reference.id  \
# 0                  HIV-1  PMID:15596521
# 1                  HIV-1  PMID:15596521
# 2                  HIV-1  PMID:15596521
# 3                  HIV-1  PMID:15596521
# 4                  HIV-1  PMID:15596521
# ...                  ...            ...
# 89316  PlasmodiumBerghei  PMID:29150238
# 89317  PlasmodiumBerghei  PMID:29150238
# 89318  PlasmodiumBerghei  PMID:29150238
# 89319  PlasmodiumBerghei  PMID:29150238
# 89320  PlasmodiumBerghei  PMID:29150238
#
#                                                   method  \
# 0      {"frequency": "", "identification": "tetramer-...
# 1      {"frequency": "", "identification": "tetramer-...
# 2      {"frequency": "", "identification": "tetramer-...
# 3      {"frequency": "", "identification": "tetramer-...
# 4      {"frequency": "", "identification": "tetramer-...
# ...                                                  ...
# 89316  {"frequency": "1//75", "identification": "tetr...
# 89317  {"frequency": "48//86", "identification": "tet...
# 89318  {"frequency": "36//86", "identification": "tet...
# 89319  {"frequency": "1//86", "identification": "tetr...
# 89320  {"frequency": "1//86", "identification": "tetr...
#
#                                                     meta  \
# 0      {"cell.subset": "CD8+", "clone.id": "", "donor...
# 1      {"cell.subset": "CD8+", "clone.id": "", "donor...
# 2      {"cell.subset": "CD8+", "clone.id": "", "donor...
# 3      {"cell.subset": "CD8+", "clone.id": "", "donor...
# 4      {"cell.subset": "CD8+", "clone.id": "", "donor...
# ...                                                  ...
# 89316  {"cell.subset": "CD8", "clone.id": "", "donor....
# 89317  {"cell.subset": "CD8", "clone.id": "", "donor....
# 89318  {"cell.subset": "CD8", "clone.id": "", "donor....
# 89319  {"cell.subset": "CD8", "clone.id": "", "donor....
# 89320  {"cell.subset": "CD8", "clone.id": "", "donor....
#
#                                                  cdr3fix vdjdb.score  \
# 0      {"cdr3": "CIVRAPGRADMRF", "cdr3_old": "CIVRAPG...           2
# 1      {"cdr3": "CASSYLPGQGDHYSNQPQHF", "cdr3_old": "...           2
# 2      {"cdr3": "CASSFEAGQGFFSNQPQHF", "cdr3_old": "C...           2
# 3      {"cdr3": "CAVPSGAGSYQLTF", "cdr3_old": "CAVPSG...           2
# 4      {"cdr3": "CASSFEPGQGFYSNQPQHF", "cdr3_old": "C...           2
# ...                                                  ...         ...
# 89316  {"cdr3": "CASSDWGSAETLYF", "cdr3_old": "CASSDW...           0
# 89317  {"cdr3": "CAARGYNQGKLIF", "cdr3_old": "CAARGYN...           1
# 89318  {"cdr3": "CATSDTNAYKVIF", "cdr3_old": "CATSDTN...           1
# 89319  {"cdr3": "CALSDTGANTGKLTF", "cdr3_old": "CALSD...           0
# 89320  {"cdr3": "CALRGNNNNRIFF", "cdr3_old": "CALRGNN...           0
#
#        web.method web.method.seq web.cdr3fix.nc web.cdr3fix.unmp
# 0            sort         sanger             no               no
# 1            sort         sanger             no               no
# 2            sort         sanger             no               no
# 3            sort         sanger             no               no
# 4            sort         sanger             no               no
# ...           ...            ...            ...              ...
# 89316        sort         sanger             no               no
# 89317        sort         sanger             no               no
# 89318        sort         sanger             no               no
# 89319        sort         sanger             no               no
# 89320        sort         sanger             no               no
#
# [89321 rows x 21 columns]

# %%
# To get the data structure as TCRdist requireabs
# To process the data frame, separate the TRA and TRB. and select all rows of HomoSpaiens
VDJdb_TRA_TRB = VDJdb[['gene', 'cdr3', 'v.segm', 'j.segm', 'species']]
VDJdb_full = VDJdb_full[["species", "cdr3.alpha", "v.alpha", "j.alpha", "cdr3.beta", "v.beta", "j.beta"]]


VDJdb_TRA = VDJdb_TRA_TRB[ VDJdb_TRA_TRB['gene'] == "TRA"]
VDJdb_TRB = VDJdb_TRA_TRB[ VDJdb_TRA_TRB['gene'] == "TRB"]

VDJdb_TRA_human = VDJdb_TRA[ VDJdb_TRA['species'] == "HomoSapiens"]
VDJdb_TRB_human = VDJdb_TRB[ VDJdb_TRB['species'] == "HomoSapiens"]
VDJdb_TRA_mouse = VDJdb_TRA[ VDJdb_TRA['species'] == "MusMusculus"]
VDJdb_TRB_mouse = VDJdb_TRB[ VDJdb_TRB['species'] == "MusMusculus"]
VDJdb_TRA_TRB_human = VDJdb_full[ VDJdb_full['species'] == "HomoSapiens"]
VDJdb_TRA_TRB_mouse = VDJdb_full[ VDJdb_full['species'] == "MusMusculus"]

# Rename the columnms to satisfied the requirement of TCRdist.
# For Human
VDJdb_TRA_human_fix = VDJdb_TRA_human.rename(columns = {'cdr3': 'cdr3_a_aa', 'v.segm': 'v_a_gene', 'j.segm': 'j_a_gene'})
VDJdb_TRB_human_fix = VDJdb_TRB_human.rename(columns = {'cdr3': 'cdr3_b_aa', 'v.segm': 'v_b_gene', 'j.segm': 'j_b_gene'})
VDJdb_TRA_TRB_human_fix = VDJdb_TRA_TRB_human.rename(columns = {'cdr3.alpha': 'cdr3_a_aa', 'v.alpha': 'v_a_gene', 
                                                                'j.alpha':'j_a_gene', 'cdr3.beta': 'cdr3_b_aa', 
                                                                'v.beta':'v_b_gene', 'j.beta':'j_b_gene'})
# For Mouse
VDJdb_TRA_mouse_fix = VDJdb_TRA_mouse.rename(columns = {'cdr3': 'cdr3_a_aa', 'v.segm': 'v_a_gene', 'j.segm': 'j_a_gene'})
VDJdb_TRB_mouse_fix = VDJdb_TRB_mouse.rename(columns = {'cdr3': 'cdr3_b_aa', 'v.segm': 'v_b_gene', 'j.segm': 'j_b_gene'})
VDJdb_TRA_TRB_mouse_fix = VDJdb_TRA_TRB_mouse.rename(columns = {'cdr3.alpha': 'cdr3_a_aa', 'v.alpha': 'v_a_gene', 
                                                                'j.alpha':'j_a_gene', 'cdr3.beta': 'cdr3_b_aa', 
                                                                'v.beta':'v_b_gene', 'j.beta':'j_b_gene'})


# Add a column called count
VDJdb_TRA_human_fix['count'] = 1
VDJdb_TRB_human_fix['count'] = 1
VDJdb_TRA_TRB_human_fix['count'] = 1
VDJdb_TRA_mouse_fix['count'] = 1
VDJdb_TRB_mouse_fix['count'] = 1
VDJdb_TRA_TRB_mouse_fix['count'] = 1


# Remove rows with NAN value
# For humanabs
VDJdb_TRA_human_fix = VDJdb_TRA_human_fix.dropna(subset = ['v_a_gene'])
VDJdb_TRB_human_fix = VDJdb_TRB_human_fix.dropna(subset = ['v_b_gene'])
VDJdb_TRA_TRB_human_fix = VDJdb_TRA_TRB_human_fix.dropna(subset = ['v_a_gene', 'cdr3_a_aa', 'cdr3_b_aa', 'v_b_gene'])

# For mouse
VDJdb_TRA_mouse_fix = VDJdb_TRA_mouse_fix.dropna(subset = ['v_a_gene'])
VDJdb_TRB_mouse_fix = VDJdb_TRB_mouse_fix.dropna(subset = ['v_b_gene'])
VDJdb_TRA_TRB_mouse_fix = VDJdb_TRA_TRB_mouse_fix.dropna(subset = ['v_a_gene', 'cdr3_a_aa', 'cdr3_b_aa', 'v_b_gene'])

# Check the NAN row exist or not.
check_NAN = VDJdb_TRA_human_fix[VDJdb_TRA_human_fix['v_a_gene'].isna()]
display(check_NAN)

# Display the data rows
display(VDJdb_TRA_human_fix)
display(VDJdb_TRB_human_fix)
display(VDJdb_TRA_TRB_human_fix)
# Out:
# Empty DataFrame
# Columns: [gene, cdr3_a_aa, v_a_gene, j_a_gene, species, count]
# Index: []
#       gene         cdr3_a_aa         v_a_gene   j_a_gene      species  count
# 0      TRA     CIVRAPGRADMRF      TRAV26-1*01  TRAJ43*01  HomoSapiens      1
# 3      TRA    CAVPSGAGSYQLTF        TRAV20*01  TRAJ28*01  HomoSapiens      1
# 5      TRA       CAVKASGSRLT         TRAV2*01        NaN  HomoSapiens      1
# 7      TRA     CAYRPPGTYKYIF  TRAV38-2/DV8*01  TRAJ40*01  HomoSapiens      1
# 9      TRA     CIVRAPGRADMRF      TRAV26-1*01  TRAJ43*01  HomoSapiens      1
# ...    ...               ...              ...        ...          ...    ...
# 89068  TRA      CAVYNQGGKLIF       TRAV8-1*01  TRAJ23*01  HomoSapiens      1
# 89070  TRA    CAVRALYNFNKFYF         TRAV3*01  TRAJ21*01  HomoSapiens      1
# 89072  TRA     CAVESYNTDKLIF        TRAV41*01  TRAJ34*01  HomoSapiens      1
# 89075  TRA    CLVGENSGGFKTIF         TRAV4*01   TRAJ9*01  HomoSapiens      1
# 89076  TRA  CAMREGQGNAGNMLTF    TRAV14/DV4*01  TRAJ39*01  HomoSapiens      1
#
# [34188 rows x 6 columns]
#       gene             cdr3_b_aa     v_b_gene    j_b_gene      species  count
# 1      TRB  CASSYLPGQGDHYSNQPQHF    TRBV13*01  TRBJ1-5*01  HomoSapiens      1
# 2      TRB   CASSFEAGQGFFSNQPQHF    TRBV13*01  TRBJ1-5*01  HomoSapiens      1
# 4      TRB   CASSFEPGQGFYSNQPQHF    TRBV13*01  TRBJ1-5*01  HomoSapiens      1
# 6      TRB  CASSYEPGQVSHYSNQPQHF    TRBV13*01  TRBJ1-5*01  HomoSapiens      1
# 8      TRB        CASSALASLNEQFF    TRBV14*01  TRBJ2-1*01  HomoSapiens      1
# ...    ...                   ...          ...         ...          ...    ...
# 89069  TRB      CASSALVAFSTDTQYF   TRBV6-4*01  TRBJ2-3*01  HomoSapiens      1
# 89071  TRB       CASSSLAGEVNEQFF   TRBV7-2*01  TRBJ2-1*01  HomoSapiens      1
# 89073  TRB   CASSSYTQRGLDYTGELFF    TRBV27*01  TRBJ2-2*01  HomoSapiens      1
# 89074  TRB       CSVEDPMGVGTEAFF  TRBV29-1*01  TRBJ1-1*01  HomoSapiens      1
# 89077  TRB     CASSQDYWGGGADTQYF   TRBV4-1*01  TRBJ2-3*01  HomoSapiens      1
#
# [47678 rows x 6 columns]
#            species         cdr3_a_aa         v_a_gene   j_a_gene  \
# 0      HomoSapiens     CIVRAPGRADMRF      TRAV26-1*01  TRAJ43*01
# 2      HomoSapiens    CAVPSGAGSYQLTF        TRAV20*01  TRAJ28*01
# 3      HomoSapiens       CAVKASGSRLT         TRAV2*01        NaN
# 4      HomoSapiens     CAYRPPGTYKYIF  TRAV38-2/DV8*01  TRAJ40*01
# 5      HomoSapiens     CIVRAPGRADMRF      TRAV26-1*01  TRAJ43*01
# ...            ...               ...              ...        ...
# 59805  HomoSapiens  CAFLNAGGTSYGKLTF      TRAV38-1*01  TRAJ52*01
# 59806  HomoSapiens      CAVYNQGGKLIF       TRAV8-1*01  TRAJ23*01
# 59807  HomoSapiens    CAVRALYNFNKFYF         TRAV3*01  TRAJ21*01
# 59808  HomoSapiens     CAVESYNTDKLIF        TRAV41*01  TRAJ34*01
# 59811  HomoSapiens  CAMREGQGNAGNMLTF    TRAV14/DV4*01  TRAJ39*01
#
#                   cdr3_b_aa    v_b_gene    j_b_gene  count
# 0      CASSYLPGQGDHYSNQPQHF   TRBV13*01  TRBJ1-5*01      1
# 2       CASSFEPGQGFYSNQPQHF   TRBV13*01  TRBJ1-5*01      1
# 3      CASSYEPGQVSHYSNQPQHF   TRBV13*01  TRBJ1-5*01      1
# 4            CASSALASLNEQFF   TRBV14*01  TRBJ2-1*01      1
# 5      CASSYLPGQGDHYSNQPQHF   TRBV13*01  TRBJ1-5*01      1
# ...                     ...         ...         ...    ...
# 59805       CASSWNGLAGDEQFF  TRBV6-2*01  TRBJ2-1*01      1
# 59806      CASSALVAFSTDTQYF  TRBV6-4*01  TRBJ2-3*01      1
# 59807       CASSSLAGEVNEQFF  TRBV7-2*01  TRBJ2-1*01      1
# 59808   CASSSYTQRGLDYTGELFF   TRBV27*01  TRBJ2-2*01      1
# 59811     CASSQDYWGGGADTQYF  TRBV4-1*01  TRBJ2-3*01      1
#
# [27006 rows x 8 columns]

# %%
# If you want to run the following code, please install tcrdist first.
import pwseqdist as pw
import pandas as pd
from tcrdist.repertoire import TCRrep
from tcrdist.vdjtools_funcs import import_vdjtools

# %%
# To process TRA chain to get distance matrix between TRA
# For the df, which will contain 34188 rows,so the distance matrix should be 34188*34188 matrix.
# My computer can not process the much big scale data. So I just select 10000*10000.
# For the df, which will contain 34188 rows,so the distance matrix should be 34188*34188 matrix.
# If any one of you can process the whole data. please do that.
df_alpha = VDJdb_TRA_human_fix[0:10000]
tr_alpha = TCRrep(cell_df = df_alpha,
            organism = 'human',
            chains = ['alpha'],
            deduplicate = False,
            db_file = "alphabeta_gammadelta_db.tsv",
            compute_distances=False)

df_beta = VDJdb_TRB_human_fix[0:10000]
tr_beta = TCRrep(cell_df = df_beta,
            organism = 'human',
            chains = ['beta'],
            deduplicate = False,
            db_file = "alphabeta_gammadelta_db.tsv",
            compute_distances=False)

df_whole = VDJdb_TRA_TRB_human_fix[0:10000]
tr_whole = TCRrep(cell_df = df_whole,
            organism = 'human',
            chains = ['alpha', 'beta'],
            deduplicate = False,
            db_file = "alphabeta_gammadelta_db.tsv",
            compute_distances=False)


#tr.compute_distances()
#tr.cpus = 4
#tr.compute_sparse_rect_distances(radius = 50, chunk_size = 80)
#tr.rw_alpha
#tr.pw_alpha

# %%
# compute_sparse_rect_distances
tr_alpha.cpus = 4
tr_alpha.compute_sparse_rect_distances(radius = 50, chunk_size = 100)
tr_alpha.rw_alpha

# %%
# compute_sparse_rect_distances
tr_beta.cpus = 4
tr_beta.compute_sparse_rect_distances(radius = 50, chunk_size = 100)
tr_beta.rw_beta
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# <10000x10000 sparse matrix of type '<class 'numpy.int16'>'
# 	with 214570 stored elements in Compressed Sparse Row format>

# %%
# compute_sparse_rect_distances
tr_beta.cpus = 4
tr_beta.compute_sparse_rect_distances(radius = 50, chunk_size = 100)
tr_alpha.rw_alpha
tr_beta.rw_beta

# %%
# Print sparse_rect_distances
print(tr_alpha.rw_alpha)
# Out:
#   (0, 0)	-1
#   (0, 4)	-1
#   (0, 7)	-1
#   (0, 10)	-1
#   (1, 1)	-1
#   (1, 5)	-1
#   (1, 8)	-1
#   (1, 11)	-1
#   (2, 2)	-1
#   (2, 6)	-1
#   (2, 9)	-1
#   (2, 12)	-1
#   (3, 3)	-1
#   (4, 0)	-1
#   (4, 4)	-1
#   (4, 7)	-1
#   (4, 10)	-1
#   (5, 1)	-1
#   (5, 5)	-1
#   (5, 8)	-1
#   (5, 11)	-1
#   (6, 2)	-1
#   (6, 6)	-1
#   (6, 9)	-1
#   (6, 12)	-1
#   :	:
#   (498, 498)	-1
#   (499, 63)	44
#   (499, 64)	47
#   (499, 65)	47
#   (499, 66)	47
#   (499, 369)	24
#   (499, 385)	24
#   (499, 388)	24
#   (499, 392)	44
#   (499, 397)	24
#   (499, 398)	44
#   (499, 403)	24
#   (499, 411)	44
#   (499, 413)	47
#   (499, 414)	24
#   (499, 417)	44
#   (499, 433)	24
#   (499, 435)	44
#   (499, 438)	21
#   (499, 450)	44
#   (499, 455)	44
#   (499, 464)	44
#   (499, 467)	44
#   (499, 493)	21
#   (499, 499)	-1

# %%
# Compute alpha chain distance matrix 
tr_alpha.compute_distances()

# %%
# Compute beta chain distance matrix 
tr_beta.compute_distances()

# %%
# Compute whole chain distance matrix 
tr_whole.compute_distances()

# %%
# Print distance matrix
tr_alpha.pw_alpha
# Out:
# array([[  0, 138, 125, ..., 152, 150, 158],
#        [138,   0, 138, ..., 110, 118, 128],
#        [125, 138,   0, ..., 140, 120, 154],
#        ...,
#        [152, 110, 140, ...,   0, 133,  80],
#        [150, 118, 120, ..., 133,   0, 144],
#        [158, 128, 154, ...,  80, 144,   0]], dtype=int16)
